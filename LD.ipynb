# %%
import string 
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
import re

# %%
df=pd.read_csv('Language Detection.csv')
df.head
# Out:
# <bound method NDFrame.head of                                                     Text Language
# 0       Nature, in the broadest sense, is the natural...  English
# 1      "Nature" can refer to the phenomena of the phy...  English
# 2      The study of nature is a large, if not the onl...  English
# 3      Although humans are part of nature, human acti...  English
# 4      [1] The word nature is borrowed from the Old F...  English
# ...                                                  ...      ...
# 10332  ನಿಮ್ಮ ತಪ್ಪು ಏನು ಬಂದಿದೆಯೆಂದರೆ ಆ ದಿನದಿಂದ ನಿಮಗೆ ಒ...  Kannada
# 10333  ನಾರ್ಸಿಸಾ ತಾನು ಮೊದಲಿಗೆ ಹೆಣಗಾಡುತ್ತಿದ್ದ ಮಾರ್ಗಗಳನ್...  Kannada
# 10334  ಹೇಗೆ ' ನಾರ್ಸಿಸಿಸಮ್ ಈಗ ಮರಿಯನ್ ಅವರಿಗೆ ಸಂಭವಿಸಿದ ಎ...  Kannada
# 10335  ಅವಳು ಈಗ ಹೆಚ್ಚು ಚಿನ್ನದ ಬ್ರೆಡ್ ಬಯಸುವುದಿಲ್ಲ ಎಂದು ...  Kannada
# 10336  ಟೆರ್ರಿ ನೀವು ನಿಜವಾಗಿಯೂ ಆ ದೇವದೂತನಂತೆ ಸ್ವಲ್ಪ ಕಾಣು...  Kannada
#
# [10337 rows x 2 columns]>

# %%
def remove_pun(text):
    for pun in string.punctuation:
        text=text.replace(pun,"")
    text=text.lower()
    return(text)

# %%
remove_pun("Nature, in the broadest sense, is the natural")
# Out:
# 'nature in the broadest sense is the natural'

# %%
df['Text'] = df['Text'].apply(remove_pun)

# %%
df.head()
# Out:
#                                                 Text Language  \
# 0   nature in the broadest sense is the natural p...  English
# 1  nature can refer to the phenomena of the physi...  English
# 2  the study of nature is a large if not the only...  English
# 3  although humans are part of nature human activ...  English
# 4  1 the word nature is borrowed from the old fre...  English
#
#                                                 text
# 0   nature in the broadest sense is the natural p...
# 1  nature can refer to the phenomena of the physi...
# 2  the study of nature is a large if not the only...
# 3  although humans are part of nature human activ...
# 4  1 the word nature is borrowed from the old fre...

# %%
from sklearn.model_selection import train_test_split

# %%
x=df.iloc[:,0]
y=df.iloc[:,1]

# %%
x
# Out:
# 0         nature in the broadest sense is the natural p...
# 1        nature can refer to the phenomena of the physi...
# 2        the study of nature is a large if not the only...
# 3        although humans are part of nature human activ...
# 4        1 the word nature is borrowed from the old fre...
#                                ...
# 10332    ನಿಮ್ಮ ತಪ್ಪು ಏನು ಬಂದಿದೆಯೆಂದರೆ ಆ ದಿನದಿಂದ ನಿಮಗೆ ಒ...
# 10333    ನಾರ್ಸಿಸಾ ತಾನು ಮೊದಲಿಗೆ ಹೆಣಗಾಡುತ್ತಿದ್ದ ಮಾರ್ಗಗಳನ್...
# 10334    ಹೇಗೆ  ನಾರ್ಸಿಸಿಸಮ್ ಈಗ ಮರಿಯನ್ ಅವರಿಗೆ ಸಂಭವಿಸಿದ ಎಲ...
# 10335    ಅವಳು ಈಗ ಹೆಚ್ಚು ಚಿನ್ನದ ಬ್ರೆಡ್ ಬಯಸುವುದಿಲ್ಲ ಎಂದು ...
# 10336    ಟೆರ್ರಿ ನೀವು ನಿಜವಾಗಿಯೂ ಆ ದೇವದೂತನಂತೆ ಸ್ವಲ್ಪ ಕಾಣು...
# Name: Text, Length: 10337, dtype: object

# %%
y
# Out:
# 0        English
# 1        English
# 2        English
# 3        English
# 4        English
#           ...
# 10332    Kannada
# 10333    Kannada
# 10334    Kannada
# 10335    Kannada
# 10336    Kannada
# Name: Language, Length: 10337, dtype: object

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2 )

# %%
x_train
# Out:
# 9137    الإصدارات ال27 الأولى من حيث عدد المقالات كل و...
# 520     43 systemic bias on wikipedia may follow that ...
# 1755    സംഭവിക്കാത്ത ഒരു കാര്യത്തെക്കുറിച്ച് ആരെങ്കിലു...
# 5242    otro ejemplo de catch22 es que necesita un pré...
# 3710    elle se distingue notamment par lobligation po...
#                               ...
# 8504    49 auktoritetsbristen och avsaknad av expertgr...
# 4685            wat dacht je van pizza eten voor vanavond
# 7372    lapprendimento automatico ha inoltre beneficia...
# 8169                                             devam et
# 7476    è così equilibrato e soave soprattutto di fron...
# Name: Text, Length: 8269, dtype: object

# %%
from sklearn import feature_extraction

# %%
from sklearn import feature_extraction
vec=feature_extraction.text.TfidfVectorizer(ngram_range=(1,2),analyzer='char')

# %%
from sklearn import pipeline
from sklearn import linear_model
model_pipe=pipeline.Pipeline([('vec',vec),('clf',linear_model.LogisticRegression())])

# %%
model_pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('vec', TfidfVectorizer(analyzer='char', ngram_range=(1, 2))),
#                 ('clf', LogisticRegression())])

# %%
predict_val =  model_pipe.predict(x_test)

# %%
from sklearn import metrics
metrics.accuracy_score(y_test,predict_val)
# Out:
# 0.9777562862669246

# %%
import pickle

# %%
new_file=open('model.pckl','wb')
pickle.dump(model_pipe,new_file)
new_file.close()

# %%
import os

# %%
os.listdir()
# Out:
# ['Language Detection.csv', 'model.pkl', 'venv']
